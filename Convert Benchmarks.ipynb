# %%
import os.path

import cirq
import quantumcircuitbenchmarks.cirq as qcb
class generators(int):
    def bv(n, **kwargs):
        return qcb.generate_bv([1]*(n-1), **kwargs)
    def cnx_halfborrowed(n, **kwargs):
        '''Only odd number of qubits supported.'''
        rn = (n + 3) // 2
        assert n == rn+rn-3, 'Unsupported number of qubits'
        return qcb.generate_cnu_halfborrowed(rn, **kwargs)
    def cnx_dirty(n, m=None, **kwargs):
        '''Even n will be longer circuits (if m is unspecified)'''
        if m is None:
            rn = (n + 4) // 2
            m = rn - 3 if n % 2 == 1 else rn - 4
            assert rn + m == n, f'{rn}, {n}, {m}'
        else:
            rn = n
        return qcb.generate_dirty_multicontrol(rn, m, **kwargs)
    cnx_inplace = qcb.generate_cnx_linear
    cnx_logancilla = qcb.generate_cnx_log_depth
    #cnx_any = qcb.generate_cnx_n_m
    def grovers(n, m=None, num_rounds=None, **kwargs):
        '''Even n will be longer circuits (if m is unspecified)'''
        if m is None:
            rn = (n + 4) // 2
            m = rn - 3 if n % 2 == 1 else rn - 4
            assert rn + m == n, f'{rn}, {n}, {m}'
        else:
            rn = n
        return qcb.generate_grover_integer_search_circuit(
                    rn, m, 2**rn-1, num_rounds=num_rounds, **kwargs)
    def incrementer_borrowedbit(r, **kwargs):
        return qcb.generate_incrementer_borrowedbit(r-1, **kwargs)
    def qaoa_random(n, prob=0.5, p=1, seed=0, **kwargs):
        return qcb.generate_random_QAOA(n, prob, p, seed=seed, **kwargs)
    def qaoa_random1(n, prob=0.05, p=1, seed=1, **kwargs):
        return qcb.generate_random_QAOA(n, prob, p, seed=seed, **kwargs)
    def qaoa_random2(n, prob=0.1, p=1, seed=2, **kwargs):
        return qcb.generate_random_QAOA(n, prob, p, seed=seed, **kwargs)
    def qaoa_random3(n, prob=0.15, p=1, seed=3, **kwargs):
        return qcb.generate_random_QAOA(n, prob, p, seed=seed, **kwargs)
    def qaoa_complete(n, prob=1, p=1, seed=0, **kwargs):
        return qcb.generate_random_QAOA(n, prob, p, seed=seed, **kwargs)
    #qaoa = qcb.generate_QAOA_circuit
    cuccaro_adder = qcb.generate_cuccaro_adder
    qft_adder = qcb.generate_qft_adder
    takahashi_adder = qcb.generate_takahashi_adder

# %%
def save_circuit_interactions(c, fname, assert_width=None, allow_toffoli=False):
    qubits = sorted(c.all_qubits())
    if assert_width is not None:
        assert len(qubits) == assert_width, (
            f'Not the expected circuit width: {len(qubits)} != {assert_width}')
    qubit_map = {q: i for i, q in enumerate(qubits)}
    interactions = []
    used_set = set(range(len(qubits)))
    depth = 0
    for op in c.all_operations():
        if len(op.qubits) < 2: continue
        if isinstance(op.gate, (cirq.MeasurementGate, cirq.ResetChannel)):
            continue
        if len(op.qubits) > 2+bool(allow_toffoli):
            raise ValueError(f'Operation on more than two qubits: {op}')
        qubit_ids = [qubit_map[q] for q in op.qubits]
        if any(qi in used_set for qi in qubit_ids):
            used_set.clear()
            depth += 1
        used_set.update(qubit_ids)
        interactions.append(f'{" ".join(map(str, qubit_ids))}\n')
    with open(fname, 'w') as f:
        f.write('===\n')
        f.write(f'n={len(qubits)}\n')
        f.write(f'depth={depth}\n')
        f.write(f'gates={len(interactions)}\n')
        f.write('---\n')
        for line in interactions:
            f.write(line)
        f.write('===\n')
    return len(qubits), depth, len(interactions)
#save_circuit_interactions(generators.bv(5), 'benchmark_files/bv.cint', 5)

# %%
def save(dirname, name, n):
    func = getattr(generators, name)
    print(f'Generating "{name}" for {n} qubits...')
    c2 = func(n)
    fname = os.path.join(dirname, f'{name}-{n}.cint')
    ret = save_circuit_interactions(c2, fname, assert_width=n)
    print(f'  Saved "{fname}"')
    c3 = func(n, to_toffoli=True)
    fname = os.path.join(dirname, f'{name}-{n}-compile3.cint')
    ret3 = save_circuit_interactions(c3, fname, assert_width=n, allow_toffoli=True)
    print(f'  Saved "{fname}"')
    cnot_count = 0
    for op in c2.all_operations():
        assert len(op.qubits) <= 2
        cnot_count += len(op.qubits) == 2
    toff_count = 0
    for op in c3.all_operations():
        assert len(op.qubits) <= 3
        toff_count += len(op.qubits) == 3
    qubit_count = len(c2.all_qubits())
    print(f'  {qubit_count:-3} & {toff_count:-3} & {cnot_count:-3}')
    return ret

# %%
for k in generators.__dict__.keys():
    if k.startswith('_'): continue
    print(k)
# Out:
# bv
# cnx_halfborrowed
# cnx_dirty
# cnx_inplace
# cnx_logancilla
# grovers
# incrementer_borrowedbit
# qaoa_random
# qaoa_random1
# qaoa_random2
# qaoa_random3
# qaoa_complete
# cuccaro_adder
# qft_adder
# takahashi_adder

# %%
max_n = 20
save('benchmark_files', 'bv', max_n)
# Out:
# Generating "bv" for 20 qubits...
#   Saved "benchmark_files/bv-20.cint"
#   Saved "benchmark_files/bv-20-compile3.cint"
#    20 &   0 &  19
# (20, 19, 19)

# %%
save('benchmark_files', 'cnx_halfborrowed', max_n-1)
# Out:
# Generating "cnx_halfborrowed" for 19 qubits...
#   Saved "benchmark_files/cnx_halfborrowed-19.cint"
#   Saved "benchmark_files/cnx_halfborrowed-19-compile3.cint"
#    19 &  32 & 256
# (19, 238, 256)

# %%
save('benchmark_files', 'cnx_dirty', 11)
# Out:
# Generating "cnx_dirty" for 11 qubits...
#   Saved "benchmark_files/cnx_dirty-11.cint"
#   Saved "benchmark_files/cnx_dirty-11-compile3.cint"
#    11 &  16 & 128
# (11, 118, 128)

# %%
save('benchmark_files', 'cnx_logancilla', max_n-1)
# Out:
# Generating "cnx_logancilla" for 19 qubits...
#   Saved "benchmark_files/cnx_logancilla-19.cint"
#   Saved "benchmark_files/cnx_logancilla-19-compile3.cint"
#    19 &  17 & 136
# (19, 52, 136)

# %%
r = None
if max_n-1 <= 22:
    r = save('benchmark_files', 'cnx_inplace', 4)
r
# Out:
# Generating "cnx_inplace" for 4 qubits...
#   Saved "benchmark_files/cnx_inplace-4.cint"
#   Saved "benchmark_files/cnx_inplace-4-compile3.cint"
#     4 &  54 & 490
# (4, 485, 490)

# %%
save('benchmark_files', 'qaoa_random1', max_n)
# Out:
# Generating "qaoa_random1" for 20 qubits...
#   Saved "benchmark_files/qaoa_random1-20.cint"
#   Saved "benchmark_files/qaoa_random1-20-compile3.cint"
#    20 &   0 &  20
# (20, 8, 20)

# %%
save('benchmark_files', 'qaoa_random2', max_n)
# Out:
# Generating "qaoa_random2" for 20 qubits...
#   Saved "benchmark_files/qaoa_random2-20.cint"
#   Saved "benchmark_files/qaoa_random2-20-compile3.cint"
#    20 &   0 &  30
# (20, 10, 30)

# %%
save('benchmark_files', 'qaoa_random3', max_n)
# Out:
# Generating "qaoa_random3" for 20 qubits...
#   Saved "benchmark_files/qaoa_random3-20.cint"
#   Saved "benchmark_files/qaoa_random3-20-compile3.cint"
#    20 &   0 &  58
# (20, 18, 58)

# %%
save('benchmark_files', 'qaoa_complete', 10)
# Out:
# Generating "qaoa_complete" for 10 qubits...
#   Saved "benchmark_files/qaoa_complete-10.cint"
#   Saved "benchmark_files/qaoa_complete-10-compile3.cint"
#    10 &   0 &  90
# (10, 34, 90)

# %%
save('benchmark_files', 'cuccaro_adder', max_n)
# Out:
# Generating "cuccaro_adder" for 20 qubits...
#   Saved "benchmark_files/cuccaro_adder-20.cint"
#   Saved "benchmark_files/cuccaro_adder-20-compile3.cint"
#    20 &  18 & 190
# (20, 165, 190)

# %%
save('benchmark_files', 'qft_adder', 16)
# Out:
# Generating "qft_adder" for 16 qubits...
#   Saved "benchmark_files/qft_adder-16.cint"
#   Saved "benchmark_files/qft_adder-16-compile3.cint"
#    16 &   0 &  92
# (16, 29, 92)

# %%
save('benchmark_files', 'takahashi_adder', max_n)
# Out:
# Generating "takahashi_adder" for 20 qubits...
#   Saved "benchmark_files/takahashi_adder-20.cint"
#   Saved "benchmark_files/takahashi_adder-20-compile3.cint"
#    20 &  18 & 188
# (20, 171, 188)

# %%
save('benchmark_files', 'incrementer_borrowedbit', 5)
# Out:
# Generating "incrementer_borrowedbit" for 5 qubits...
#   Saved "benchmark_files/incrementer_borrowedbit-5.cint"
#   Saved "benchmark_files/incrementer_borrowedbit-5-compile3.cint"
#     5 &  50 & 448
# (5, 442, 448)

# %%
save('benchmark_files', 'grovers', 9)
# Out:
# Generating "grovers" for 9 qubits...
#   Saved "benchmark_files/grovers-9.cint"
#   Saved "benchmark_files/grovers-9-compile3.cint"
#     9 &  84 & 672
# (9, 455, 672)

# %%
generators(5).bv()
# Out:
# 0: ───H───────@───H───────────────
#               │
# 1: ───H───────┼───@───H───────────
#               │   │
# 2: ───H───────┼───┼───@───H───────
#               │   │   │
# 3: ───H───────┼───┼───┼───@───H───
#               │   │   │   │
# 4: ───X───H───X───X───X───X───H───

# %%
generators(5).cnx_halfborrowed()  # Must be odd
# Out:
#                                                                ┌──┐                                    ┌──┐
# 0: ───T───X─────────────────────────────────────────────────────@─────T^-1───X───@───X──────@───X───────@─────T───X────────────────────────────────────────────────────@───T^-1───X───@───X──────@───X──────@───────
#           │                                                     │            │   │   │      │   │       │         │                                                    │          │   │   │      │   │      │
# 1: ───T───@─────────────────────────────────────────────────────┼────────────@───┼───@──────┼───@───────┼T────────@────────────────────────────────────────────────────┼──────────@───┼───@──────┼───@──────┼───────
#                                                                 │                │          │           │                                                              │              │          │          │
# 2: ───T───────────X───T──────────X───T^-1───X───T^-1───X───T────┼────────────────┼──────────┼───────────┼─────────────────X───T──────────X───T^-1───X───T^-1───X───────┼──────────────┼──────────┼──────────┼───────
#                   │              │          │          │        │                │          │           │                 │              │          │          │       │              │          │          │
# 3: ───H───T───X───@───T^-1───X───@───X──────@───X──────@───H────┼H────T──────────┼──────────┼───────────┼─────────────X───@───T^-1───X───@───X──────@───X──────@───H───┼──────────────┼──────────┼──────────┼───────
#               │              │       │          │               │                │          │           │             │              │       │          │              │              │          │          │
# 4: ───T───────@──────────────@───────@──────────@──────H───T────X─────T──────────X───T^-1───X───T^-1────X─────H───T───@──────────────@───────@──────────@──────H───T───X───T──────────X───T^-1───X───T^-1───X───H───
#                                                                └──┘                                    └──┘

# %%
generators(5).cnx_dirty(to_toffoli=False)  # Better when odd
# Out:
#                                                                ┌──┐                                    ┌──┐
# 0: ───T───X─────────────────────────────────────────────────────@─────T^-1───X───@───X──────@───X───────@─────T───X────────────────────────────────────────────────────@───T^-1───X───@───X──────@───X──────@───────
#           │                                                     │            │   │   │      │   │       │         │                                                    │          │   │   │      │   │      │
# 1: ───T───@─────────────────────────────────────────────────────┼────────────@───┼───@──────┼───@───────┼T────────@────────────────────────────────────────────────────┼──────────@───┼───@──────┼───@──────┼───────
#                                                                 │                │          │           │                                                              │              │          │          │
# 2: ───T───────────X───T──────────X───T^-1───X───T^-1───X───T────┼────────────────┼──────────┼───────────┼─────────────────X───T──────────X───T^-1───X───T^-1───X───────┼──────────────┼──────────┼──────────┼───────
#                   │              │          │          │        │                │          │           │                 │              │          │          │       │              │          │          │
# 3: ───H───T───X───@───T^-1───X───@───X──────@───X──────@───H────┼H────T──────────┼──────────┼───────────┼─────────────X───@───T^-1───X───@───X──────@───X──────@───H───┼──────────────┼──────────┼──────────┼───────
#               │              │       │          │               │                │          │           │             │              │       │          │              │              │          │          │
# 4: ───T───────@──────────────@───────@──────────@──────H───T────X─────T──────────X───T^-1───X───T^-1────X─────H───T───@──────────────@───────@──────────@──────H───T───X───T──────────X───T^-1───X───T^-1───X───H───
#                                                                └──┘                                    └──┘

# %%
generators(5).cnx_inplace()
# Out:
#                                                                                                         ┌──┐                                                                                                        ┌──┐                                                                                                             ┌──┐                                                                                                        ┌──┐                                                                            ┌──┐                                                                                                                                                                              ┌──┐                                                    ┌──┐                                                                                                                                                                              ┌──┐                                                                                                         ┌──┐                                                                                                     ┌──┐           ┌──┐   ┌──┐                                                    ┌──┐                                                                                                                                                                              ┌──┐                                                    ┌──┐                                                                                                                                                                              ┌──┐                                                                                                         ┌──┐                                                                                                     ┌──┐                                                                    ┌──┐                                                                                                                                                                              ┌──┐                                                    ┌──┐                                                                                                                                                                              ┌──┐                                                        ┌──┐           ┌──┐   ┌──┐                                                    ┌──┐                                                                                                                                                                              ┌──┐                                                    ┌──┐                                                                                                                                                                              ┌──┐                                                        ┌──┐                                                                                                                         ┌──┐                                                            ┌──┐                                                        ┌──┐                                                                                                             ┌──┐                               ┌──┐                                    ┌──┐                                                        ┌──┐                     ┌──┐   ┌──┐                                                    ┌──┐                                                                                                                                                                              ┌──┐                                                    ┌──┐                                                                                                                                                                              ┌──┐                                                               ...
# 0: ───T───X────────────────────────────────────────────────────────@───T^-1───X───@───X──────@───X───────@─────T───X───────────────────────────────────────────────────────────@───T^-1───X───@───X──────@───X───────@─────T───X────────────────────────────────────────────────────────────────@───T^-1───X───@───X──────@───X───────@─────T───X───────────────────────────────────────────────────────────@───T^-1───X───@───X──────@───X───────@─────────────────────@───@───H───T───X───@───T^-1───X───@───X──────@───X───────@─────H───T───@──────────────@───────@──────────@──────T───────────────────@──────────────@───────@──────────@──────H───T───────X───@───T^-1───X───@───X──────@───X──────@───H─────@────H───T───X───@───T^-1───X───@───X──────@───X───────@─────H───T───@──────────────@───────@──────────@──────T───────────────────@──────────────@───────@──────────@──────H───T───────X───@───T^-1───X───@───X──────@───X──────@───H────@─────T───X────────────────────────────────────────────────────────────@───T^-1───X───@───X──────@───X───────@─────T───X────────────────────────────────────────────────────────@───T^-1───X───@───X──────@───X───────@───────────────@──────@────H───T───X───@───T^-1───X───@───X──────@───X───────@─────H───T───@──────────────@───────@──────────@──────T───────────────────@──────────────@───────@──────────@──────H───T───────X───@───T^-1───X───@───X──────@───X──────@───H─────@────H───T───X───@───T^-1───X───@───X──────@───X───────@─────H───T───@──────────────@───────@──────────@──────T───────────────────@──────────────@───────@──────────@──────H───T───────X───@───T^-1───X───@───X──────@───X──────@───H────@─────T───X────────────────────────────────────────────────────────────@───T^-1───X───@───X──────@───X───────@─────T───X────────────────────────────────────────────────────────@───T^-1───X───@───X──────@───X───────@─────────────@───@───H───T───X───@───T^-1───X───@───X──────@───X───────@─────H───T───@──────────────@───────@──────────@──────T───────────────────@──────────────@───────@──────────@──────H───T───────X───@───T^-1───X───@───X──────@───X──────@───H─────@────H───T───X───@───T^-1───X───@───X──────@───X───────@─────H───T───@──────────────@───────@──────────@──────T───────────────────@──────────────@───────@──────────@──────H───T───────X───@───T^-1───X───@───X──────@───X──────@───H────@─────T───X───────────@───T^-1───X───@───X──────@───X───────@───────────────@──────@────H───T───X───@───T^-1───X───@───X──────@───X───────@─────H───T───@──────────────@───────@──────────@──────T───────────────────@──────────────@───────@──────────@──────H───T───────X───@───T^-1───X───@───X──────@───X──────@───H─────@────H───T───X───@───T^-1───X───@───X──────@───X───────@─────H───T───@──────────────@───────@──────────@──────T───────────────────@──────────────@───────@──────────@──────H───T───────X───@───T^-1───X───@───X──────@───X──────@───H────@─────T───X───────────@───T^-1───X───@───X──────@───X───────@─────────────X───X───T───────────X───T──────────X───T^-1───X───T^-1───X───T───────────X───T──────────X───T^-1───X───T^-1────X─────T───────────────────X───T──────────X───T^-1───X───T^-1────X─────T───────────X───T──────────X───T^-1───X───T^-1───X─────X────X───T───────────X───T──────────X───T^-1───X───T^-1───X───T───────────X───T──────────X───T^-1───X───T^-1────X─────T────────────────────────────X─────T──────────X───T^-1───X───T^-1────X─────T───────────X───T──────────X───T^-1───X───T^-1───X─────X────X──────X────────────@─────@─────H───T───X───@───T^-1───X───@───X──────@───X───────@─────H───T───@──────────────@───────@──────────@──────T───────────────────@──────────────@───────@──────────@──────H───T───────X───@───T^-1───X───@───X──────@───X──────@───H─────@────H───T───X───@───T^-1───X───@───X──────@───X───────@─────H───T───@──────────────@───────@──────────@──────T───────────────────@──────────────@───────@──────────@──────H───T───────X───@───T^-1───X───@───X──────@───X──────@───H────@─────T───X────────────────────────────────────────────────────── ...
#           │                                                        │          │   │   │      │   │       │         │                                                           │          │   │   │      │   │       │         │                                                                │          │   │   │      │   │       │         │                                                           │          │   │   │      │   │       │                     │   │           │   │          │   │   │      │   │       │             │              │       │          │                          │              │       │          │                  │   │          │   │   │      │   │      │         │            │   │          │   │   │      │   │       │             │              │       │          │                          │              │       │          │                  │   │          │   │   │      │   │      │        │         │                                                            │          │   │   │      │   │       │         │                                                        │          │   │   │      │   │       │               │      │            │   │          │   │   │      │   │       │             │              │       │          │                          │              │       │          │                  │   │          │   │   │      │   │      │         │            │   │          │   │   │      │   │       │             │              │       │          │                          │              │       │          │                  │   │          │   │   │      │   │      │        │         │                                                            │          │   │   │      │   │       │         │                                                        │          │   │   │      │   │       │             │   │           │   │          │   │   │      │   │       │             │              │       │          │                          │              │       │          │                  │   │          │   │   │      │   │      │         │            │   │          │   │   │      │   │       │             │              │       │          │                          │              │       │          │                  │   │          │   │   │      │   │      │        │         │           │          │   │   │      │   │       │               │      │            │   │          │   │   │      │   │       │             │              │       │          │                          │              │       │          │                  │   │          │   │   │      │   │      │         │            │   │          │   │   │      │   │       │             │              │       │          │                          │              │       │          │                  │   │          │   │   │      │   │      │        │         │           │          │   │   │      │   │       │             │   │               │              │          │          │               │              │          │           │                         │              │          │           │                 │              │          │          │     │    │               │              │          │          │               │              │          │           │                                  │                │          │           │                 │              │          │          │     │    │                   │     │             │   │          │   │   │      │   │       │             │              │       │          │                          │              │       │          │                  │   │          │   │   │      │   │      │         │            │   │          │   │   │      │   │       │             │              │       │          │                          │              │       │          │                  │   │          │   │   │      │   │      │        │         │                                                       ...
# 1: ───T───@────────────────────────────────────────────────────────┼──────────@───┼───@──────┼───@───────┼T────────@───────────────────────────────────────────────────────────┼──────────@───┼───@──────┼───@───────┼T────────@────────────────────────────────────────────────────────────────┼──────────@───┼───@──────┼───@───────┼T────────@───────────────────────────────────────────────────────────┼──────────@───┼───@──────┼───@───────┼X────T───────────────┼───┼───────────@───┼──────────@───┼───@──────┼───@───────┼H────T───────X───@───T^-1───X───@───X──────@───X──────@───H───@───H───T───X───@───T^-1───X───@───X──────@───X──────@───H───T───@───┼──────────@───┼───@──────┼───@──────┼───@────X┼────T───────@───┼──────────@───┼───@──────┼───@───────┼H────T───────X───@───T^-1───X───@───X──────@───X──────@───H───@───H───T───X───@───T^-1───X───@───X──────@───X──────@───H───T───@───┼──────────@───┼───@──────┼───@──────┼───@────┼T────────@────────────────────────────────────────────────────────────┼──────────@───┼───@──────┼───@───────┼T────────@────────────────────────────────────────────────────────┼──────────@───┼───@──────┼───@───────┼X────T─────────┼──────┼────────────@───┼──────────@───┼───@──────┼───@───────┼H────T───────X───@───T^-1───X───@───X──────@───X──────@───H───@───H───T───X───@───T^-1───X───@───X──────@───X──────@───H───T───@───┼──────────@───┼───@──────┼───@──────┼───@────X┼────T───────@───┼──────────@───┼───@──────┼───@───────┼H────T───────X───@───T^-1───X───@───X──────@───X──────@───H───@───H───T───X───@───T^-1───X───@───X──────@───X──────@───H───T───@───┼──────────@───┼───@──────┼───@──────┼───@────┼T────────@────────────────────────────────────────────────────────────┼──────────@───┼───@──────┼───@───────┼T────────@────────────────────────────────────────────────────────┼──────────@───┼───@──────┼───@───────┼X────T───────┼───┼───────────@───┼──────────@───┼───@──────┼───@───────┼H────T───────X───@───T^-1───X───@───X──────@───X──────@───H───@───H───T───X───@───T^-1───X───@───X──────@───X──────@───H───T───@───┼──────────@───┼───@──────┼───@──────┼───@────X┼────T───────@───┼──────────@───┼───@──────┼───@───────┼H────T───────X───@───T^-1───X───@───X──────@───X──────@───H───@───H───T───X───@───T^-1───X───@───X──────@───X──────@───H───T───@───┼──────────@───┼───@──────┼───@──────┼───@────┼T────────@───────────┼──────────@───┼───@──────┼───@───────┼X────T─────────┼──────┼────────────@───┼──────────@───┼───@──────┼───@───────┼H────T───────X───@───T^-1───X───@───X──────@───X──────@───H───@───H───T───X───@───T^-1───X───@───X──────@───X──────@───H───T───@───┼──────────@───┼───@──────┼───@──────┼───@────X┼────T───────@───┼──────────@───┼───@──────┼───@───────┼H────T───────X───@───T^-1───X───@───X──────@───X──────@───H───@───H───T───X───@───T^-1───X───@───X──────@───X──────@───H───T───@───┼──────────@───┼───@──────┼───@──────┼───@────┼T────────@───────────┼──────────@───┼───@──────┼───@───────┼X────────────┼───┼───────────────┼──────────────┼──────────┼──────────┼───────────────┼──────────────┼──────────┼───────────┼─────────X───────────────┼──────────────┼──────────┼───────────┼─────────────────┼──────────────┼──────────┼──────────┼─────┼────┼───────────────┼──────────────┼──────────┼──────────┼───────────────┼──────────────┼──────────┼───────────┼─────────X───Z^(-1/16)───X───X────┼T───────────────┼──────────┼───────────┼─────────────────┼──────────────┼──────────┼──────────┼─────┼────┼───────────────────┼─────┼─────────────@───┼──────────@───┼───@──────┼───@───────┼H────T───────X───@───T^-1───X───@───X──────@───X──────@───H───@───H───T───X───@───T^-1───X───@───X──────@───X──────@───H───T───@───┼──────────@───┼───@──────┼───@──────┼───@────X┼────T───────@───┼──────────@───┼───@──────┼───@───────┼H────T───────X───@───T^-1───X───@───X──────@───X──────@───H───@───H───T───X───@───T^-1───X───@───X──────@───X──────@───H───T───@───┼──────────@───┼───@──────┼───@──────┼───@────┼T────────@────────────────────────────────────────────────────── ...
#                                                                    │              │          │           │                                                                     │              │          │           │                                                                          │              │          │           │                                                                     │              │          │           │                     │   │               │              │          │           │                 │              │          │          │       │               │              │          │          │               │              │          │          │   │     │                │              │          │           │                 │              │          │          │       │               │              │          │          │               │              │          │          │   │    │                                                                      │              │          │           │                                                                  │              │          │           │               │      │                │              │          │           │                 │              │          │          │       │               │              │          │          │               │              │          │          │   │     │                │              │          │           │                 │              │          │          │       │               │              │          │          │               │              │          │          │   │    │                                                                      │              │          │           │                                                                  │              │          │           │             │   │               │              │          │           │                 │              │          │          │       │               │              │          │          │               │              │          │          │   │     │                │              │          │           │                 │              │          │          │       │               │              │          │          │               │              │          │          │   │    │                     │              │          │           │               │      │                │              │          │           │                 │              │          │          │       │               │              │          │          │               │              │          │          │   │     │                │              │          │           │                 │              │          │          │       │               │              │          │          │               │              │          │          │   │    │                     │              │          │           │             │   │               │              │          │          │               │              │          │           │         │               │              │          │           │                 │              │          │          │     │    │               │              │          │          │               │              │          │           │         │                        │                │          │           │                 │              │          │          │     │    │                   │     │                 │              │          │           │                 │              │          │          │       │               │              │          │          │               │              │          │          │   │     │                │              │          │           │                 │              │          │          │       │               │              │          │          │               │              │          │          │   │    │                                                                 ...
# 2: ───T───@──────────────────@───────@──────────@──────T───────────┼──────────────┼──────────┼───────────┼─────────────@──────────────@───────@──────────@──────T──────────────┼──────────────┼──────────┼───────────┼─────────────────@──────────────────@───────@──────────@──────T───────────┼──────────────┼──────────┼───────────┼─────────────@──────────────@───────@──────────@──────T──────────────┼──────────────┼──────────┼───────────┼─────────────────────┼───┼───────────────┼──────────────┼──────────┼───────────┼─────────────────┼──────────────┼──────────┼──────────┼───────┼───────────────┼──────────────┼──────────┼──────────┼───────────────┼──────────────┼──────────┼──────────┼───┼─────┼────────────────┼──────────────┼──────────┼───────────┼─────────────────┼──────────────┼──────────┼──────────┼───────┼───────────────┼──────────────┼──────────┼──────────┼───────────────┼──────────────┼──────────┼──────────┼───┼────┼─────────────────@──────────────@───────@──────────@──────T───────────┼──────────────┼──────────┼───────────┼─────────────@──────────────@───────@──────────@──────T───────────┼──────────────┼──────────┼───────────┼───────────────┼──────┼────────────────┼──────────────┼──────────┼───────────┼─────────────────┼──────────────┼──────────┼──────────┼───────┼───────────────┼──────────────┼──────────┼──────────┼───────────────┼──────────────┼──────────┼──────────┼───┼─────┼────────────────┼──────────────┼──────────┼───────────┼─────────────────┼──────────────┼──────────┼──────────┼───────┼───────────────┼──────────────┼──────────┼──────────┼───────────────┼──────────────┼──────────┼──────────┼───┼────┼─────────────────@──────────────@───────@──────────@──────T───────────┼──────────────┼──────────┼───────────┼─────────────@──────────────@───────@──────────@──────X───────────┼──────────────┼──────────┼───────────┼─────────────┼───┼───────────────┼──────────────┼──────────┼───────────┼─────────────────┼──────────────┼──────────┼──────────┼───────X───────────────┼──────────────┼──────────┼──────────┼───────────────┼──────────────┼──────────┼──────────┼───┼─────┼────────────────┼──────────────┼──────────┼───────────┼─────────────────┼──────────────┼──────────┼──────────┼───────X───────────────┼──────────────┼──────────┼──────────┼───────────────┼──────────────┼──────────┼──────────┼───┼────┼─────────X───────────┼──────────────┼──────────┼───────────┼─────────X────X┼─────X┼────────────────┼──────────────┼──────────┼───────────┼─────────────────┼──────────────┼──────────┼──────────┼───────X───────────────┼──────────────┼──────────┼──────────┼───────────────┼──────────────┼──────────┼──────────┼───┼─────┼────────────────┼──────────────┼──────────┼───────────┼─────────────────┼──────────────┼──────────┼──────────┼───────X───X───────────┼──────────────┼──────────┼──────────┼───────────────┼──────────────┼──────────┼──────────┼───┼────┼─────────X───────────┼──────────────┼──────────┼───────────┼─────────X───@───@───H───T───X───@───T^-1───X───@───X──────@───X──────@───H───T───@───┼──────────@───┼───@──────┼───@───────┼T────────┼───────────@───┼──────────@───┼───@──────┼───@───────┼H────T───────X───@───T^-1───X───@───X──────@───X──────@────H┼────@───H───T───X───@───T^-1───X───@───X──────@───X──────@───H───T───@───┼──────────@───┼───@──────┼───@───────┼T────────┼───────────────────@────┼────────────@───┼───@──────┼───@───────┼H────T───────X───@───T^-1───X───@───X──────@───X──────@────H┼────@──────Z^(-1/8)────X┼─────┼T────────────────┼──────────────┼──────────┼───────────┼─────────────────┼──────────────┼──────────┼──────────┼───────┼───────────────┼──────────────┼──────────┼──────────┼───────────────┼──────────────┼──────────┼──────────┼───┼─────┼────────────────┼──────────────┼──────────┼───────────┼─────────────────┼──────────────┼──────────┼──────────┼───────┼───────────────┼──────────────┼──────────┼──────────┼───────────────┼──────────────┼──────────┼──────────┼───┼────┼─────────────────@──────────────@───────@──────────@──────T───── ...
#           │                  │       │          │                  │              │          │           │             │              │       │          │                     │              │          │           │                 │                  │       │          │                  │              │          │           │             │              │       │          │                     │              │          │           │                     │   │               │              │          │           │                 │              │          │          │       │               │              │          │          │               │              │          │          │   │     │                │              │          │           │                 │              │          │          │       │               │              │          │          │               │              │          │          │   │    │                 │              │       │          │                  │              │          │           │             │              │       │          │                  │              │          │           │               │      │                │              │          │           │                 │              │          │          │       │               │              │          │          │               │              │          │          │   │     │                │              │          │           │                 │              │          │          │       │               │              │          │          │               │              │          │          │   │    │                 │              │       │          │                  │              │          │           │             │              │       │          │                  │              │          │           │             │   │               │              │          │           │                 │              │          │          │                       │              │          │          │               │              │          │          │   │     │                │              │          │           │                 │              │          │          │                       │              │          │          │               │              │          │          │   │    │         │           │              │          │           │         │     │      │                │              │          │           │                 │              │          │          │                       │              │          │          │               │              │          │          │   │     │                │              │          │           │                 │              │          │          │                       │              │          │          │               │              │          │          │   │    │         │           │              │          │           │         │                   │              │       │          │                  │   │          │   │   │      │   │       │         │           │   │          │   │   │      │   │       │             │              │       │          │            │                │              │       │          │                  │   │          │   │   │      │   │       │         │                   │    │            │   │   │      │   │       │             │              │       │          │            │                        │     │                 │              │          │           │                 │              │          │          │       │               │              │          │          │               │              │          │          │   │     │                │              │          │           │                 │              │          │          │       │               │              │          │          │               │              │          │          │   │    │                 │              │       │          │             ...
# 3: ───T───X───────@───T^-1───X───@───X──────@───X──────@───H───T───X───T──────────X───T^-1───X───T^-1────X─────H───T───X───@───T^-1───X───@───X──────@───X──────@───H───T──────X───T──────────X───T^-1───X───T^-1────X─────H───@───T───X───────@───T^-1───X───@───X──────@───X──────@───H───T───X───T──────────X───T^-1───X───T^-1────X─────H───T───X───@───T^-1───X───@───X──────@───X──────@───H───T──────X───T──────────X───T^-1───X───T^-1────X─────H───@───X───────┼───┼───────────────┼──────────────┼──────────┼───────────┼─────────────────┼──────────────┼──────────┼──────────┼───────X───────────────┼──────────────┼──────────┼──────────┼───────────────┼──────────────┼──────────┼──────────┼───┼─────┼────────────────┼──────────────┼──────────┼───────────┼─────────────────┼──────────────┼──────────┼──────────┼───────X───────────────┼──────────────┼──────────┼──────────┼───────────────┼──────────────┼──────────┼──────────┼───┼────┼─────────X───T───X───@───T^-1───X───@───X──────@───X──────@───H───T───X───T──────────X───T^-1───X───T^-1────X─────H───T───X───@───T^-1───X───@───X──────@───X──────@───H───T───X───T──────────X───T^-1───X───T^-1────X─────H───X────X┼─────X┼────────────────┼──────────────┼──────────┼───────────┼─────────────────┼──────────────┼──────────┼──────────┼───────X───────────────┼──────────────┼──────────┼──────────┼───────────────┼──────────────┼──────────┼──────────┼───┼─────┼────────────────┼──────────────┼──────────┼───────────┼─────────────────┼──────────────┼──────────┼──────────┼───────X───X───────────┼──────────────┼──────────┼──────────┼───────────────┼──────────────┼──────────┼──────────┼───┼────┼─────────X───T───X───@───T^-1───X───@───X──────@───X──────@───H───T───X───T──────────X───T^-1───X───T^-1────X─────H───T───X───@───T^-1───X───@───X──────@───X──────@───H───T───X───T──────────X───T^-1───X───T^-1────X─────H───X───X───X───T───────────X───T──────────X───T^-1───X───T^-1────X─────T───────────X───T──────────X───T^-1───X───T^-1───X───T───────────────────X───T──────────X───T^-1───X───T^-1───X───T───────────X───T──────────X───T^-1───X───T^-1───X───X─────X────T───────────X───T──────────X───T^-1───X───T^-1────X─────T───────────X───T──────────X───T^-1───X───T^-1───X───T───────────────────X───T──────────X───T^-1───X───T^-1───X───T───────────X───T──────────X───T^-1───X───T^-1───X───X────X─────X───@───H───T───X───T──────────X───T^-1───X───T^-1────X─────H───@─────X──────X────T───────────X───T──────────X───T^-1───X───T^-1────X─────T───────────X───T──────────X───T^-1───X───T^-1───X───T───────────────────X───T──────────X───T^-1───X───T^-1───X───T───────────X───T──────────X───T^-1───X───T^-1───X───X─────X────T───────────X───T──────────X───T^-1───X───T^-1────X─────T───────────X───T──────────X───T^-1───X───T^-1───X───T───────────────────X───T──────────X───T^-1───X───T^-1───X───T───────────X───T──────────X───T^-1───X───T^-1───X───X────X─────X───@───H───T───X───T──────────X───T^-1───X───T^-1────X─────H───@───X───T───────────@──────────────@───────@──────────@──────H───T───────X───@───T^-1───X───@───X──────@───X───────@─────H───@───H───T───X───@───T^-1───X───@───X──────@───X───────@─────H───T───@──────────────@───────@──────────@────────────@────X───T───────@──────────────@───────@──────────@──────H───T───────X───@───T^-1───X───@───X──────@───X───────@─────H───@───H───────────T───X────@─────T^-1───X───@───X──────@───X───────@─────H───T───@──────────────@───────@──────────@────────────@────T^-1───X───────────X┼─────┼─────────────────┼──────────────┼──────────┼───────────┼─────────────────┼──────────────┼──────────┼──────────┼───────X───────────────┼──────────────┼──────────┼──────────┼───────────────┼──────────────┼──────────┼──────────┼───┼─────┼────────────────┼──────────────┼──────────┼───────────┼─────────────────┼──────────────┼──────────┼──────────┼───────X───────────────┼──────────────┼──────────┼──────────┼───────────────┼──────────────┼──────────┼──────────┼───┼────┼─────────X───T───X───@───T^-1───X───@───X──────@───X──────@───H─ ...
#                   │              │          │          │                                                                   │              │          │          │                                                              │               │              │          │          │                                                                   │              │          │          │                                                              │           │   │               │              │          │           │                 │              │          │          │                       │              │          │          │               │              │          │          │   │     │                │              │          │           │                 │              │          │          │                       │              │          │          │               │              │          │          │   │    │         │           │              │          │          │                                                                   │              │          │          │                                                           │     │      │                │              │          │           │                 │              │          │          │                       │              │          │          │               │              │          │          │   │     │                │              │          │           │                 │              │          │          │                       │              │          │          │               │              │          │          │   │    │         │           │              │          │          │                                                                   │              │          │          │                                                           │                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      │     │                 │              │          │           │                 │              │          │          │                       │              │          │          │               │              │          │          │   │     │                │              │          │           │                 │              │          │          │                       │              │          │          │               │              │          │          │   │    │         │           │              │          │          │      ...
# 4: ───H───H───T───X───T──────────X───T^-1───X───T^-1───X───H───H───T───────────────────────────────────────────────────────X───T──────────X───T^-1───X───T^-1───X───H───T^-1───────────────────────────────────────────────────X───T───H───T───X───T──────────X───T^-1───X───T^-1───X───H───H───T───────────────────────────────────────────────────────X───T──────────X───T^-1───X───T^-1───X───H───T^-1───────────────────────────────────────────────────X───T───H───X───X───T───────────X───T──────────X───T^-1───X───T^-1────X─────T───────────X───T──────────X───T^-1───X───T^-1───X───T───────────────────X───T──────────X───T^-1───X───T^-1───X───T───────────X───T──────────X───T^-1───X───T^-1───X───X─────X────T───────────X───T──────────X───T^-1───X───T^-1────X─────T───────────X───T──────────X───T^-1───X───T^-1───X───T───────────────────X───T──────────X───T^-1───X───T^-1───X───T───────────X───T──────────X───T^-1───X───T^-1───X───X────X─────X───@───H───T───X───T──────────X───T^-1───X───T^-1───X───H───H───T───────────────────────────────────────────────────────X───T──────────X───T^-1───X───T^-1───X───H───────────────────────────────────────────────────────@─────X──────X────T───────────X───T──────────X───T^-1───X───T^-1────X─────T───────────X───T──────────X───T^-1───X───T^-1───X───T───────────────────X───T──────────X───T^-1───X───T^-1───X───T───────────X───T──────────X───T^-1───X───T^-1───X───X─────X────T───────────X───T──────────X───T^-1───X───T^-1────X─────T───────────X───T──────────X───T^-1───X───T^-1───X───T───────────────────X───T──────────X───T^-1───X───T^-1───X───T───────────X───T──────────X───T^-1───X───T^-1───X───X────X─────X───@───H───T───X───T──────────X───T^-1───X───T^-1───X───H───H───T───────────────────────────────────────────────────────X───T──────────X───T^-1───X───T^-1───X───H───────────────────────────────────────────────────────@──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────X─────X─────T───────────X───T──────────X───T^-1───X───T^-1────X─────T───────────X───T──────────X───T^-1───X───T^-1───X───T───────────────────X───T──────────X───T^-1───X───T^-1───X───T───────────X───T──────────X───T^-1───X───T^-1───X───X─────X────T───────────X───T──────────X───T^-1───X───T^-1────X─────T───────────X───T──────────X───T^-1───X───T^-1───X───T───────────────────X───T──────────X───T^-1───X───T^-1───X───T───────────X───T──────────X───T^-1───X───T^-1───X───X────X─────X───@───H───T───X───T──────────X───T^-1───X───T^-1───X───H─ ...
#                                                                                                         └──┘                                                                                                        └──┘                                                                                                             └──┘                                                                                                        └──┘                                                                            └──┘                                                                                                                                                                              └──┘                                                    └──┘                                                                                                                                                                              └──┘                                                                                                         └──┘                                                                                                     └──┘           └──┘   └──┘                                                    └──┘                                                                                                                                                                              └──┘                                                    └──┘                                                                                                                                                                              └──┘                                                                                                         └──┘                                                                                                     └──┘                                                                    └──┘                                                                                                                                                                              └──┘                                                    └──┘                                                                                                                                                                              └──┘                                                        └──┘           └──┘   └──┘                                                    └──┘                                                                                                                                                                              └──┘                                                    └──┘                                                                                                                                                                              └──┘                                                        └──┘                                                                                                                         └──┘                                                            └──┘                                                        └──┘                                                                                                             └──┘                               └──┘                                    └──┘                                                        └──┘                     └──┘   └──┘                                                    └──┘                                                                                                                                                                              └──┘                                                    └──┘                                                                                                                                                                              └──┘                                                               ...

# %%
generators(5).cnx_logancilla()
# Out:
#                                                    ┌─────┐
# 0: ───T───X───@───T^-1───X───@───X──────@───X───────@────────T^-1───X───────────────────────────────────────────────────────@───T──────X───@───X───@───X───@───────
#           │   │          │   │   │      │   │       │               │                                                       │          │   │   │   │   │   │
# 1: ───T───@───┼──────────@───┼───@──────┼───@───────┼T^-1───────────@───────────────────────────────────────────────────────┼──────────@───┼───@───┼───@───┼───────
#               │              │          │           │                                                                       │              │       │       │
# 2: ───T───────┼──────────────┼──────────┼───────────┼───────────────────────X───T──────────X───T^-1───X───T^-1───X──────────┼──────────────┼───────┼───────┼───────
#               │              │          │           │                       │              │          │          │          │              │       │       │
# 3: ───H───T───┼──────────────┼──────────┼───────────┼───────────────────X───@───T^-1───X───@───X──────@───X──────@───H──────┼──────────────┼───────┼───────┼───────
#               │              │          │           │                   │              │       │          │                 │              │       │       │
# 4: ───H───T───X───T──────────X───T^-1───X───T^-1────X────────H──────T───@──────────────@───────@──────────@──────H───T^-1───X───T^-1───────X───T───X───T───X───H───
#                                                    └─────┘

# %%
#generators.cnx_any(4, 1)

# %%
generators(5).grovers()
# Out:
#                   ┌──┐                                    ┌──┐                                                            ┌──┐              ┌──┐          ┌──┐          ┌──┐                                                        ┌──┐                                                            ┌──┐              ┌──┐          ┌──┐          ┌──┐                                                        ┌──┐                                                            ┌──┐              ┌──┐          ┌──┐          ┌──┐                                                        ┌──┐                                                            ┌──┐              ┌──┐          ┌──┐          ┌──┐                                                        ┌──┐                                                            ┌──┐              ┌──┐          ┌──┐          ┌──┐                                                        ┌──┐                                                            ┌──┐                                    ┌──┐
# 0: ───H───T───X────@─────T^-1───X───@───X──────@───X───────@─────T───X─────────────────────────────────────────────────────@─────T^-1───X────@─────X───────@─────X───────@─────H───X───T───X───@───T^-1───X───@───X──────@───X───────@─────T───X─────────────────────────────────────────────────────@─────T^-1───X────@─────X───────@─────X───────@─────X───H───T───X───@───T^-1───X───@───X──────@───X───────@─────T───X─────────────────────────────────────────────────────@─────T^-1───X────@─────X───────@─────X───────@─────H───X───T───X───@───T^-1───X───@───X──────@───X───────@─────T───X─────────────────────────────────────────────────────@─────T^-1───X────@─────X───────@─────X───────@─────X───H───T───X───@───T^-1───X───@───X──────@───X───────@─────T───X─────────────────────────────────────────────────────@─────T^-1───X────@─────X───────@─────X───────@─────H───X───T───X───@───T^-1───X───@───X──────@───X───────@─────T───X─────────────────────────────────────────────────────@─────T^-1───X───@───X──────@───X───────@─────X───H───
#               │    │            │   │   │      │   │       │         │                                                     │            │    │     │       │     │       │                 │   │          │   │   │      │   │       │         │                                                     │            │    │     │       │     │       │                 │   │          │   │   │      │   │       │         │                                                     │            │    │     │       │     │       │                 │   │          │   │   │      │   │       │         │                                                     │            │    │     │       │     │       │                 │   │          │   │   │      │   │       │         │                                                     │            │    │     │       │     │       │                 │   │          │   │   │      │   │       │         │                                                     │            │   │   │      │   │       │
# 1: ───H───T───@────┼────────────@───┼───@──────┼───@───────┼T────────@─────────────────────────────────────────────────────┼────────────@────┼─────@───────┼─────@───────┼H────X───T───────@───┼──────────@───┼───@──────┼───@───────┼T────────@─────────────────────────────────────────────────────┼────────────@────┼─────@───────┼─────@───────┼X────H───T───────@───┼──────────@───┼───@──────┼───@───────┼T────────@─────────────────────────────────────────────────────┼────────────@────┼─────@───────┼─────@───────┼H────X───T───────@───┼──────────@───┼───@──────┼───@───────┼T────────@─────────────────────────────────────────────────────┼────────────@────┼─────@───────┼─────@───────┼X────H───T───────@───┼──────────@───┼───@──────┼───@───────┼T────────@─────────────────────────────────────────────────────┼────────────@────┼─────@───────┼─────@───────┼H────X───T───────@───┼──────────@───┼───@──────┼───@───────┼T────────@─────────────────────────────────────────────────────┼────────────@───┼───@──────┼───@───────┼X────H───────
#                    │                │          │           │                                                               │                 │             │             │                     │              │          │           │                                                               │                 │             │             │                     │              │          │           │                                                               │                 │             │             │                     │              │          │           │                                                               │                 │             │             │                     │              │          │           │                                                               │                 │             │             │                     │              │          │           │                                                               │                │          │           │
# 2: ───H───T────────┼─────@──────────┼──────────┼───────────┼────────────────────────@───────@──────────@──────H───X───T────┼─────────────────┼─────────────┼@────────────┼─────────────────────┼──────────────┼──────────┼───────────┼────────────────────────@───────@──────────@──────X───H───T────┼─────────────────┼─────────────┼@────────────┼─────────────────────┼──────────────┼──────────┼───────────┼────────────────────────@───────@──────────@──────H───X───T────┼─────────────────┼─────────────┼@────────────┼─────────────────────┼──────────────┼──────────┼───────────┼────────────────────────@───────@──────────@──────X───H───T────┼─────────────────┼─────────────┼@────────────┼─────────────────────┼──────────────┼──────────┼───────────┼────────────────────────@───────@──────────@──────H───X───T────┼─────────────────┼─────────────┼@────────────┼─────────────────────┼──────────────┼──────────┼───────────┼────────────────────────@───────@──────────@──────X───H────────┼────────────────┼──────────┼───────────┼─────────────
#                    │     │          │          │           │                        │       │          │                   │                 │             ││            │                     │              │          │           │                        │       │          │                   │                 │             ││            │                     │              │          │           │                        │       │          │                   │                 │             ││            │                     │              │          │           │                        │       │          │                   │                 │             ││            │                     │              │          │           │                        │       │          │                   │                 │             ││            │                     │              │          │           │                        │       │          │                   │                │          │           │
# 3: ───H───H───H────┼T────X──────────┼──────────┼───────────┼─────────────@───T^-1───X───@───X──────@───X──────@───H───H────┼H────X──────H────┼H────T───────┼X────────────┼─────────────────────┼──────────────┼──────────┼───────────┼─────────────@───T^-1───X───@───X──────@───X──────@───H───H────┼X────H──────H────┼H────T───────┼X────────────┼─────────────────────┼──────────────┼──────────┼───────────┼─────────────@───T^-1───X───@───X──────@───X──────@───H───H────┼H────X──────H────┼H────T───────┼X────────────┼─────────────────────┼──────────────┼──────────┼───────────┼─────────────@───T^-1───X───@───X──────@───X──────@───H───H────┼X────H──────H────┼H────T───────┼X────────────┼─────────────────────┼──────────────┼──────────┼───────────┼─────────────@───T^-1───X───@───X──────@───X──────@───H───H────┼H────X──────H────┼H────T───────┼X────────────┼─────────────────────┼──────────────┼──────────┼───────────┼─────────────@───T^-1───X───@───X──────@───X──────@───H───H────┼X────H──────────┼──────────┼───────────┼─────────────
#                    │                │          │           │             │              │          │          │            │                 │             │             │                     │              │          │           │             │              │          │          │            │                 │             │             │                     │              │          │           │             │              │          │          │            │                 │             │             │                     │              │          │           │             │              │          │          │            │                 │             │             │                     │              │          │           │             │              │          │          │            │                 │             │             │                     │              │          │           │             │              │          │          │            │                │          │           │
# 4: ───H───T────────X─────T──────────X───T^-1───X───T^-1────X─────H───T───X───T──────────X───T^-1───X───T^-1───X───H───T────X─────T───────────X─────T^-1────X─────T^-1────X─────H───H───T───────X───T──────────X───T^-1───X───T^-1────X─────H───T───X───T──────────X───T^-1───X───T^-1───X───H───T────X─────T───────────X─────T^-1────X─────T^-1────X─────H───H───T───────X───T──────────X───T^-1───X───T^-1────X─────H───T───X───T──────────X───T^-1───X───T^-1───X───H───T────X─────T───────────X─────T^-1────X─────T^-1────X─────H───H───T───────X───T──────────X───T^-1───X───T^-1────X─────H───T───X───T──────────X───T^-1───X───T^-1───X───H───T────X─────T───────────X─────T^-1────X─────T^-1────X─────H───H───T───────X───T──────────X───T^-1───X───T^-1────X─────H───T───X───T──────────X───T^-1───X───T^-1───X───H───T────X─────T───────────X─────T^-1────X─────T^-1────X─────H───H───T───────X───T──────────X───T^-1───X───T^-1────X─────H───T───X───T──────────X───T^-1───X───T^-1───X───H───T────X─────T──────────X───T^-1───X───T^-1────X─────H───────
#                   └──┘                                    └──┘                                                            └──┘              └──┘          └──┘          └──┘                                                        └──┘                                                            └──┘              └──┘          └──┘          └──┘                                                        └──┘                                                            └──┘              └──┘          └──┘          └──┘                                                        └──┘                                                            └──┘              └──┘          └──┘          └──┘                                                        └──┘                                                            └──┘              └──┘          └──┘          └──┘                                                        └──┘                                                            └──┘                                    └──┘

# %%
generators(5).incrementer_borrowedbit()
# Out:
#       ┌──┐   ┌──┐                                                    ┌──┐                                                                                                                                                                              ┌──┐                                                    ┌──┐                                                                                                                                                                              ┌──┐                                                                                                         ┌──┐                                                                                                     ┌──┐           ┌──┐   ┌──┐                                                    ┌──┐                                                                                                                                                                              ┌──┐                                                    ┌──┐                                                                                                                                                                              ┌──┐                                                                                                         ┌──┐                                                                                                     ┌──┐                                                                    ┌──┐                                                                                                                                                                              ┌──┐                                                    ┌──┐                                                                                                                                                                              ┌──┐                                                        ┌──┐           ┌──┐   ┌──┐                                                    ┌──┐                                                                                                                                                                              ┌──┐                                                    ┌──┐                                                                                                                                                                              ┌──┐                                                        ┌──┐                                                                                                                         ┌──┐                                                            ┌──┐                                                        ┌──┐                                                                                                             ┌──┐                                                            ┌──┐                                                        ┌──┐
# 0: ────@──────@─────H───T───X───@───T^-1───X───@───X──────@───X───────@─────H───T───@──────────────@───────@──────────@──────T───────────────────@──────────────@───────@──────────@──────H───T───────X───@───T^-1───X───@───X──────@───X──────@───H─────@────H───T───X───@───T^-1───X───@───X──────@───X───────@─────H───T───@──────────────@───────@──────────@──────T───────────────────@──────────────@───────@──────────@──────H───T───────X───@───T^-1───X───@───X──────@───X──────@───H────@─────T───X────────────────────────────────────────────────────────────@───T^-1───X───@───X──────@───X───────@─────T───X────────────────────────────────────────────────────────@───T^-1───X───@───X──────@───X───────@───────────────@──────@────H───T───X───@───T^-1───X───@───X──────@───X───────@─────H───T───@──────────────@───────@──────────@──────T───────────────────@──────────────@───────@──────────@──────H───T───────X───@───T^-1───X───@───X──────@───X──────@───H─────@────H───T───X───@───T^-1───X───@───X──────@───X───────@─────H───T───@──────────────@───────@──────────@──────T───────────────────@──────────────@───────@──────────@──────H───T───────X───@───T^-1───X───@───X──────@───X──────@───H────@─────T───X────────────────────────────────────────────────────────────@───T^-1───X───@───X──────@───X───────@─────T───X────────────────────────────────────────────────────────@───T^-1───X───@───X──────@───X───────@─────────────@───@───H───T───X───@───T^-1───X───@───X──────@───X───────@─────H───T───@──────────────@───────@──────────@──────T───────────────────@──────────────@───────@──────────@──────H───T───────X───@───T^-1───X───@───X──────@───X──────@───H─────@────H───T───X───@───T^-1───X───@───X──────@───X───────@─────H───T───@──────────────@───────@──────────@──────T───────────────────@──────────────@───────@──────────@──────H───T───────X───@───T^-1───X───@───X──────@───X──────@───H────@─────T───X───────────@───T^-1───X───@───X──────@───X───────@───────────────@──────@────H───T───X───@───T^-1───X───@───X──────@───X───────@─────H───T───@──────────────@───────@──────────@──────T───────────────────@──────────────@───────@──────────@──────H───T───────X───@───T^-1───X───@───X──────@───X──────@───H─────@────H───T───X───@───T^-1───X───@───X──────@───X───────@─────H───T───@──────────────@───────@──────────@──────T───────────────────@──────────────@───────@──────────@──────H───T───────X───@───T^-1───X───@───X──────@───X──────@───H────@─────T───X───────────@───T^-1───X───@───X──────@───X───────@─────────────X───X───T───────────X───T──────────X───T^-1───X───T^-1───X───T───────────X───T──────────X───T^-1───X───T^-1────X─────T───────────────────X───T──────────X───T^-1───X───T^-1────X─────T───────────X───T──────────X───T^-1───X───T^-1───X─────X────X───T───────────X───T──────────X───T^-1───X───T^-1───X───T───────────X───T──────────X───T^-1───X───T^-1────X─────T───────────────────X───T──────────X───T^-1───X───T^-1────X─────T───────────X───T──────────X───T^-1───X───T^-1───X─────X────X───
#        │      │             │   │          │   │   │      │   │       │             │              │       │          │                          │              │       │          │                  │   │          │   │   │      │   │      │         │            │   │          │   │   │      │   │       │             │              │       │          │                          │              │       │          │                  │   │          │   │   │      │   │      │        │         │                                                            │          │   │   │      │   │       │         │                                                        │          │   │   │      │   │       │               │      │            │   │          │   │   │      │   │       │             │              │       │          │                          │              │       │          │                  │   │          │   │   │      │   │      │         │            │   │          │   │   │      │   │       │             │              │       │          │                          │              │       │          │                  │   │          │   │   │      │   │      │        │         │                                                            │          │   │   │      │   │       │         │                                                        │          │   │   │      │   │       │             │   │           │   │          │   │   │      │   │       │             │              │       │          │                          │              │       │          │                  │   │          │   │   │      │   │      │         │            │   │          │   │   │      │   │       │             │              │       │          │                          │              │       │          │                  │   │          │   │   │      │   │      │        │         │           │          │   │   │      │   │       │               │      │            │   │          │   │   │      │   │       │             │              │       │          │                          │              │       │          │                  │   │          │   │   │      │   │      │         │            │   │          │   │   │      │   │       │             │              │       │          │                          │              │       │          │                  │   │          │   │   │      │   │      │        │         │           │          │   │   │      │   │       │             │   │               │              │          │          │               │              │          │           │                         │              │          │           │                 │              │          │          │     │    │               │              │          │          │               │              │          │           │                         │              │          │           │                 │              │          │          │     │    │
# 1: ────┼X─────┼T────────────@───┼──────────@───┼───@──────┼───@───────┼H────T───────X───@───T^-1───X───@───X──────@───X──────@───H───@───H───T───X───@───T^-1───X───@───X──────@───X──────@───H───T───@───┼──────────@───┼───@──────┼───@──────┼───@────X┼────T───────@───┼──────────@───┼───@──────┼───@───────┼H────T───────X───@───T^-1───X───@───X──────@───X──────@───H───@───H───T───X───@───T^-1───X───@───X──────@───X──────@───H───T───@───┼──────────@───┼───@──────┼───@──────┼───@────┼T────────@────────────────────────────────────────────────────────────┼──────────@───┼───@──────┼───@───────┼T────────@────────────────────────────────────────────────────────┼──────────@───┼───@──────┼───@───────┼X────T─────────┼──────┼────────────@───┼──────────@───┼───@──────┼───@───────┼H────T───────X───@───T^-1───X───@───X──────@───X──────@───H───@───H───T───X───@───T^-1───X───@───X──────@───X──────@───H───T───@───┼──────────@───┼───@──────┼───@──────┼───@────X┼────T───────@───┼──────────@───┼───@──────┼───@───────┼H────T───────X───@───T^-1───X───@───X──────@───X──────@───H───@───H───T───X───@───T^-1───X───@───X──────@───X──────@───H───T───@───┼──────────@───┼───@──────┼───@──────┼───@────┼T────────@────────────────────────────────────────────────────────────┼──────────@───┼───@──────┼───@───────┼T────────@────────────────────────────────────────────────────────┼──────────@───┼───@──────┼───@───────┼X────T───────┼───┼───────────@───┼──────────@───┼───@──────┼───@───────┼H────T───────X───@───T^-1───X───@───X──────@───X──────@───H───@───H───T───X───@───T^-1───X───@───X──────@───X──────@───H───T───@───┼──────────@───┼───@──────┼───@──────┼───@────X┼────T───────@───┼──────────@───┼───@──────┼───@───────┼H────T───────X───@───T^-1───X───@───X──────@───X──────@───H───@───H───T───X───@───T^-1───X───@───X──────@───X──────@───H───T───@───┼──────────@───┼───@──────┼───@──────┼───@────┼T────────@───────────┼──────────@───┼───@──────┼───@───────┼X────T─────────┼──────┼────────────@───┼──────────@───┼───@──────┼───@───────┼H────T───────X───@───T^-1───X───@───X──────@───X──────@───H───@───H───T───X───@───T^-1───X───@───X──────@───X──────@───H───T───@───┼──────────@───┼───@──────┼───@──────┼───@────X┼────T───────@───┼──────────@───┼───@──────┼───@───────┼H────T───────X───@───T^-1───X───@───X──────@───X──────@───H───@───H───T───X───@───T^-1───X───@───X──────@───X──────@───H───T───@───┼──────────@───┼───@──────┼───@──────┼───@────┼T────────@───────────┼──────────@───┼───@──────┼───@───────┼X────────────┼───┼───────────────┼──────────────┼──────────┼──────────┼───────────────┼──────────────┼──────────┼───────────┼─────────X───────────────┼──────────────┼──────────┼───────────┼─────────────────┼──────────────┼──────────┼──────────┼─────┼────┼───────────────┼──────────────┼──────────┼──────────┼───────────────┼──────────────┼──────────┼───────────┼─────────X───────────────┼──────────────┼──────────┼───────────┼─────────────────┼──────────────┼──────────┼──────────┼─────┼────┼───
#        │      │                 │              │          │           │                 │              │          │          │       │               │              │          │          │               │              │          │          │   │     │                │              │          │           │                 │              │          │          │       │               │              │          │          │               │              │          │          │   │    │                                                                      │              │          │           │                                                                  │              │          │           │               │      │                │              │          │           │                 │              │          │          │       │               │              │          │          │               │              │          │          │   │     │                │              │          │           │                 │              │          │          │       │               │              │          │          │               │              │          │          │   │    │                                                                      │              │          │           │                                                                  │              │          │           │             │   │               │              │          │           │                 │              │          │          │       │               │              │          │          │               │              │          │          │   │     │                │              │          │           │                 │              │          │          │       │               │              │          │          │               │              │          │          │   │    │                     │              │          │           │               │      │                │              │          │           │                 │              │          │          │       │               │              │          │          │               │              │          │          │   │     │                │              │          │           │                 │              │          │          │       │               │              │          │          │               │              │          │          │   │    │                     │              │          │           │             │   │               │              │          │          │               │              │          │           │         │               │              │          │           │                 │              │          │          │     │    │               │              │          │          │               │              │          │           │         │               │              │          │           │                 │              │          │          │     │    │
# 2: ────┼T─────┼─────────────────┼──────────────┼──────────┼───────────┼─────────────────┼──────────────┼──────────┼──────────┼───────┼───────────────┼──────────────┼──────────┼──────────┼───────────────┼──────────────┼──────────┼──────────┼───┼─────┼────────────────┼──────────────┼──────────┼───────────┼─────────────────┼──────────────┼──────────┼──────────┼───────┼───────────────┼──────────────┼──────────┼──────────┼───────────────┼──────────────┼──────────┼──────────┼───┼────┼─────────────────@──────────────@───────@──────────@──────T───────────┼──────────────┼──────────┼───────────┼─────────────@──────────────@───────@──────────@──────T───────────┼──────────────┼──────────┼───────────┼───────────────┼──────┼────────────────┼──────────────┼──────────┼───────────┼─────────────────┼──────────────┼──────────┼──────────┼───────┼───────────────┼──────────────┼──────────┼──────────┼───────────────┼──────────────┼──────────┼──────────┼───┼─────┼────────────────┼──────────────┼──────────┼───────────┼─────────────────┼──────────────┼──────────┼──────────┼───────┼───────────────┼──────────────┼──────────┼──────────┼───────────────┼──────────────┼──────────┼──────────┼───┼────┼─────────────────@──────────────@───────@──────────@──────T───────────┼──────────────┼──────────┼───────────┼─────────────@──────────────@───────@──────────@──────X───────────┼──────────────┼──────────┼───────────┼─────────────┼───┼───────────────┼──────────────┼──────────┼───────────┼─────────────────┼──────────────┼──────────┼──────────┼───────X───────────────┼──────────────┼──────────┼──────────┼───────────────┼──────────────┼──────────┼──────────┼───┼─────┼────────────────┼──────────────┼──────────┼───────────┼─────────────────┼──────────────┼──────────┼──────────┼───────X───────────────┼──────────────┼──────────┼──────────┼───────────────┼──────────────┼──────────┼──────────┼───┼────┼─────────X───────────┼──────────────┼──────────┼───────────┼─────────X────X┼─────X┼────────────────┼──────────────┼──────────┼───────────┼─────────────────┼──────────────┼──────────┼──────────┼───────X───────────────┼──────────────┼──────────┼──────────┼───────────────┼──────────────┼──────────┼──────────┼───┼─────┼────────────────┼──────────────┼──────────┼───────────┼─────────────────┼──────────────┼──────────┼──────────┼───────X───X───────────┼──────────────┼──────────┼──────────┼───────────────┼──────────────┼──────────┼──────────┼───┼────┼─────────X───────────┼──────────────┼──────────┼───────────┼─────────X───@───@───H───T───X───@───T^-1───X───@───X──────@───X──────@───H───T───@───┼──────────@───┼───@──────┼───@───────┼T────────┼───────────@───┼──────────@───┼───@──────┼───@───────┼H────T───────X───@───T^-1───X───@───X──────@───X──────@────H┼────@───H───T───X───@───T^-1───X───@───X──────@───X──────@───H───T───@───┼──────────@───┼───@──────┼───@───────┼T────────┼───────────@───┼──────────@───┼───@──────┼───@───────┼H────T───────X───@───T^-1───X───@───X──────@───X──────@────H┼────@───
#        │      │                 │              │          │           │                 │              │          │          │       │               │              │          │          │               │              │          │          │   │     │                │              │          │           │                 │              │          │          │       │               │              │          │          │               │              │          │          │   │    │                 │              │       │          │                  │              │          │           │             │              │       │          │                  │              │          │           │               │      │                │              │          │           │                 │              │          │          │       │               │              │          │          │               │              │          │          │   │     │                │              │          │           │                 │              │          │          │       │               │              │          │          │               │              │          │          │   │    │                 │              │       │          │                  │              │          │           │             │              │       │          │                  │              │          │           │             │   │               │              │          │           │                 │              │          │          │                       │              │          │          │               │              │          │          │   │     │                │              │          │           │                 │              │          │          │                       │              │          │          │               │              │          │          │   │    │         │           │              │          │           │         │     │      │                │              │          │           │                 │              │          │          │                       │              │          │          │               │              │          │          │   │     │                │              │          │           │                 │              │          │          │                       │              │          │          │               │              │          │          │   │    │         │           │              │          │           │         │                   │              │       │          │                  │   │          │   │   │      │   │       │         │           │   │          │   │   │      │   │       │             │              │       │          │            │                │              │       │          │                  │   │          │   │   │      │   │       │         │           │   │          │   │   │      │   │       │             │              │       │          │            │
# 3: ────┼X─────┼─────────────────┼──────────────┼──────────┼───────────┼─────────────────┼──────────────┼──────────┼──────────┼───────X───────────────┼──────────────┼──────────┼──────────┼───────────────┼──────────────┼──────────┼──────────┼───┼─────┼────────────────┼──────────────┼──────────┼───────────┼─────────────────┼──────────────┼──────────┼──────────┼───────X───────────────┼──────────────┼──────────┼──────────┼───────────────┼──────────────┼──────────┼──────────┼───┼────┼─────────X───T───X───@───T^-1───X───@───X──────@───X──────@───H───T───X───T──────────X───T^-1───X───T^-1────X─────H───T───X───@───T^-1───X───@───X──────@───X──────@───H───T───X───T──────────X───T^-1───X───T^-1────X─────H───X────X┼─────X┼────────────────┼──────────────┼──────────┼───────────┼─────────────────┼──────────────┼──────────┼──────────┼───────X───────────────┼──────────────┼──────────┼──────────┼───────────────┼──────────────┼──────────┼──────────┼───┼─────┼────────────────┼──────────────┼──────────┼───────────┼─────────────────┼──────────────┼──────────┼──────────┼───────X───X───────────┼──────────────┼──────────┼──────────┼───────────────┼──────────────┼──────────┼──────────┼───┼────┼─────────X───T───X───@───T^-1───X───@───X──────@───X──────@───H───T───X───T──────────X───T^-1───X───T^-1────X─────H───T───X───@───T^-1───X───@───X──────@───X──────@───H───T───X───T──────────X───T^-1───X───T^-1────X─────H───X───X───X───T───────────X───T──────────X───T^-1───X───T^-1────X─────T───────────X───T──────────X───T^-1───X───T^-1───X───T───────────────────X───T──────────X───T^-1───X───T^-1───X───T───────────X───T──────────X───T^-1───X───T^-1───X───X─────X────T───────────X───T──────────X───T^-1───X───T^-1────X─────T───────────X───T──────────X───T^-1───X───T^-1───X───T───────────────────X───T──────────X───T^-1───X───T^-1───X───T───────────X───T──────────X───T^-1───X───T^-1───X───X────X─────X───@───H───T───X───T──────────X───T^-1───X───T^-1────X─────H───@─────X──────X────T───────────X───T──────────X───T^-1───X───T^-1────X─────T───────────X───T──────────X───T^-1───X───T^-1───X───T───────────────────X───T──────────X───T^-1───X───T^-1───X───T───────────X───T──────────X───T^-1───X───T^-1───X───X─────X────T───────────X───T──────────X───T^-1───X───T^-1────X─────T───────────X───T──────────X───T^-1───X───T^-1───X───T───────────────────X───T──────────X───T^-1───X───T^-1───X───T───────────X───T──────────X───T^-1───X───T^-1───X───X────X─────X───@───H───T───X───T──────────X───T^-1───X───T^-1────X─────H───@───X───T───────────@──────────────@───────@──────────@──────H───T───────X───@───T^-1───X───@───X──────@───X───────@─────H───@───H───T───X───@───T^-1───X───@───X──────@───X───────@─────H───T───@──────────────@───────@──────────@────────────@────X───T───────@──────────────@───────@──────────@──────H───T───────X───@───T^-1───X───@───X──────@───X───────@─────H───@───H───T───X───@───T^-1───X───@───X──────@───X───────@─────H───T───@──────────────@───────@──────────@────────────@────────
#        │      │                 │              │          │           │                 │              │          │          │                       │              │          │          │               │              │          │          │   │     │                │              │          │           │                 │              │          │          │                       │              │          │          │               │              │          │          │   │    │         │           │              │          │          │                                                                   │              │          │          │                                                           │     │      │                │              │          │           │                 │              │          │          │                       │              │          │          │               │              │          │          │   │     │                │              │          │           │                 │              │          │          │                       │              │          │          │               │              │          │          │   │    │         │           │              │          │          │                                                                   │              │          │          │                                                           │
# 4: ────X──────X─────T───────────X───T──────────X───T^-1───X───T^-1────X─────T───────────X───T──────────X───T^-1───X───T^-1───X───T───────────────────X───T──────────X───T^-1───X───T^-1───X───T───────────X───T──────────X───T^-1───X───T^-1───X───X─────X────T───────────X───T──────────X───T^-1───X───T^-1────X─────T───────────X───T──────────X───T^-1───X───T^-1───X───T───────────────────X───T──────────X───T^-1───X───T^-1───X───T───────────X───T──────────X───T^-1───X───T^-1───X───X────X─────X───@───H───T───X───T──────────X───T^-1───X───T^-1───X───H───H───T───────────────────────────────────────────────────────X───T──────────X───T^-1───X───T^-1───X───H───────────────────────────────────────────────────────@─────X──────X────T───────────X───T──────────X───T^-1───X───T^-1────X─────T───────────X───T──────────X───T^-1───X───T^-1───X───T───────────────────X───T──────────X───T^-1───X───T^-1───X───T───────────X───T──────────X───T^-1───X───T^-1───X───X─────X────T───────────X───T──────────X───T^-1───X───T^-1────X─────T───────────X───T──────────X───T^-1───X───T^-1───X───T───────────────────X───T──────────X───T^-1───X───T^-1───X───T───────────X───T──────────X───T^-1───X───T^-1───X───X────X─────X───@───H───T───X───T──────────X───T^-1───X───T^-1───X───H───H───T───────────────────────────────────────────────────────X───T──────────X───T^-1───X───T^-1───X───H───────────────────────────────────────────────────────@───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#       └──┘   └──┘                                                    └──┘                                                                                                                                                                              └──┘                                                    └──┘                                                                                                                                                                              └──┘                                                                                                         └──┘                                                                                                     └──┘           └──┘   └──┘                                                    └──┘                                                                                                                                                                              └──┘                                                    └──┘                                                                                                                                                                              └──┘                                                                                                         └──┘                                                                                                     └──┘                                                                    └──┘                                                                                                                                                                              └──┘                                                    └──┘                                                                                                                                                                              └──┘                                                        └──┘           └──┘   └──┘                                                    └──┘                                                                                                                                                                              └──┘                                                    └──┘                                                                                                                                                                              └──┘                                                        └──┘                                                                                                                         └──┘                                                            └──┘                                                        └──┘                                                                                                             └──┘                                                            └──┘                                                        └──┘

# %%
generators(5).qaoa_random1()
generators(5).qaoa_random2()
generators(5).qaoa_random3()
# Out:
#       ┌──┐           ┌──┐
# 0: ────@─────────@────@─────────@───X───────────────
#        │         │    │         │
# 1: ────┼X────────┼────┼─────────┼───────────────────
#        │         │    │         │
# 2: ────X─────Z───X────┼X────────┼───────────────────
#                       │         │
# 3: ───────────────────┼─────────┼───@───────@───X───
#                       │         │   │       │
# 4: ───────────────────X─────Z───X───X───Z───X───X───
#       └──┘           └──┘

# %%
generators(5).qaoa_complete()
# Out:
#                               ┌──┐       ┌──┐   ┌──┐       ┌──┐   ┌──┐       ┌──┐
# 0: ───@───────@───@───────@────@──────────@──────@──────────@──────X────────────────────────────────────────────
#       │       │   │       │    │          │      │          │
# 1: ───X───Z───X───┼───────┼────┼@─────────┼@─────┼@─────────┼@─────@──────────@─────X───────────────────────────
#                   │       │    ││         ││     ││         ││     │          │
# 2: ───────────────X───Z───X────┼X────Z────┼X─────┼┼─────────┼┼─────┼@─────────┼@────@───────@───X───────────────
#                                │          │      ││         ││     ││         ││    │       │
# 3: ────────────────────────────X─────Z────X──────┼X────Z────┼X─────┼X────Z────┼X────┼───────┼───@───────@───X───
#                                                  │          │      │          │     │       │   │       │
# 4: ──────────────────────────────────────────────X─────Z────X──────X─────Z────X─────X───Z───X───X───Z───X───X───
#                               └──┘       └──┘   └──┘       └──┘   └──┘       └──┘

# %%
generators(6).cuccaro_adder()  # Must be even
# Out:
#       ┌──┐                                                                ┌──┐                                                            ┌──┐
# 0: ──────────X───T───────@──────────────@───────@──────────@────────────────@────T────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────@──────────────@───────@──────────@──────────────X───────
#              │           │              │       │          │                │                                                                                                                                         │              │       │          │              │
# 1: ────@─────@───H───T───X───@───T^-1───X───@───X──────@───X──────@───H────X┼────T───────@──────────────@───────@──────────@────────────────@────T───────@──────────────@───────@──────────@──────────────X───H───T───X───@───T^-1───X───@───X──────@───X──────@───H───@───@───
#        │                     │              │          │          │        ││            │              │       │          │                │            │              │       │          │              │               │              │          │          │           │
# 2: ────┼@────────────────────┼──────────────┼──────────┼──────────┼────────@┼────H───T───X───@───T^-1───X───@───X──────@───X──────@───H────@┼────H───T───X───@───T^-1───X───@───X──────@───X──────@───H───@───@───────────┼──────────────┼──────────┼──────────┼───────────┼───
#        ││                    │              │          │          │         │                │              │          │          │        ││                │              │          │          │           │           │              │          │          │           │
# 3: ────X┼────T───────────────X───T──────────X───T^-1───X───T^-1───X───X─────X────T───────────┼──────────────┼──────────┼──────────┼────────┼┼────────────────┼──────────────┼──────────┼──────────┼───────────┼───────────X───T──────────X───T^-1───X───T^-1───X───X───────X───
#         │                                                                                    │              │          │          │        ││                │              │          │          │           │
# 4: ─────X────T───────────────────────────────────────────────────────────────────────────────X───T──────────X───T^-1───X───T^-1───X───X────┼X────T───────────X───T──────────X───T^-1───X───T^-1───X───X───────X────────────────────────────────────────────────────────────────
#                                                                                                                                            │
# 5: ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────X───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#       └──┘                                                                └──┘                                                            └──┘

# %%
generators(6).qft_adder()  # Must be even
# Out:
#                   ┌───────┐                ┌──────┐                     ┌────────┐
# 0: ────────────────@──────────@────────H────@─────────H───────@───────────@───────────────────────
#                    │          │             │                 │           │
# 1: ───────@────────┼─────H────@^0.25───@────┼─────────@───────@^-0.25────H┼──────────@────────────
#           │        │                   │    │         │                   │          │
# 2: ───H───@^0.5────@^0.25─────@────────┼────┼@────────┼───────@───────────@^-0.25────@^-0.5───H───
#                               │        │    ││        │       │
# 3: ───────────────────────────┼────────┼────@┼────────@^0.5───@^0.25──────────────────────────────
#                               │        │     │
# 4: ───────────────────────────┼────────@─────@^0.5────────────────────────────────────────────────
#                               │
# 5: ───────────────────────────@───────────────────────────────────────────────────────────────────
#                   └───────┘                └──────┘                     └────────┘

# %%
generators(6).takahashi_adder()  # Must be even
# Out:
#       ┌───┐                                                                                                                                                                              ┌──┐                                                        ┌──┐       ┌──┐
# 0: ────T──────────────────@──────────────@───────@──────────@──────T────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────@──────────────@───────@──────────@────────────@───────────────
#                           │              │       │          │                                                                                                                                           │              │       │          │            │
# 1: ────@──────@───H───T───X───@───T^-1───X───@───X──────@───X──────@───H───T───@──────────────@───────@──────────@──────T───────────────────@──────────────@───────@──────────@────────────@────H───T───X───@───T^-1───X───@───X──────@───X──────@────H┼────@────@─────
#        │      │               │              │          │          │           │              │       │          │                          │              │       │          │            │                │              │          │          │     │    │    │
# 2: ────┼@─────X───H───T───────┼──────────────┼──────────┼──────────┼───────────X───@───T^-1───X───@───X──────@───X──────@───H───@───H───T───X───@───T^-1───X───@───X──────@───X──────@────H┼────────────────┼──────────────┼──────────┼──────────┼─────┼────X────┼@────
#        ││                     │              │          │          │               │              │          │          │       │               │              │          │          │     │                │              │          │          │     │         ││
# 3: ────┼┼T────────────────────X───T──────────X───T^-1───X───T^-1───X───T───────────┼──────────────┼──────────┼──────────┼───────┼───────────────┼──────────────┼──────────┼──────────┼─────┼────────────────X───T──────────X───T^-1───X───T^-1───X─────X─────────┼┼────
#        ││                                                                          │              │          │          │       │               │              │          │          │     │                                                                     ││
# 4: ────X┼─────T────────────────────────────────────────────────────────────────────X───T──────────X───T^-1───X───T^-1───X───T───┼───────────────X───T──────────X───T^-1───X───T^-1───X─────X─────────────────────────────────────────────────────────────────────X┼────
#         │                                                                                                                       │                                                                                                                                 │
# 5: ─────X───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────X─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────X────
#       └───┘                                                                                                                                                                              └──┘                                                        └──┘       └──┘

# %%
import cirq

# %%
cirq.Circuit(cirq.decompose(cirq.CCZ(*cirq.LineQubit.range(3))))
# Out:
# 0: ───T────────────@────────────────────────────────@─────────────────────────────@────────────────────────────@───────────────────────────
#                    │                                │                             │                            │
# 1: ───T───Y^-0.5───@───Y^0.5───@───T^-1────Y^-0.5───@────────Y^0.5───@───Y^-0.5───@──────Y^0.5────@───Y^-0.5───@──────Y^0.5────@───────────
#                                │                                     │                            │                            │
# 2: ───T───Y^-0.5───────────────@───Y^0.5───T────────Y^-0.5───────────@───Y^0.5────T^-1───Y^-0.5───@───Y^0.5────T^-1───Y^-0.5───@───Y^0.5───
